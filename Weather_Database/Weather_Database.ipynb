# %%
# 1). Generate a new set of 2000 random latitudes and longitudes.
from citipy import citipy
import numpy as np
import pandas as pd

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

coordinates = list(lat_lngs)

# %%
# 2). Get the nearest city using the citipy module.
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
   
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 770

# %%
# 3). Perform an API call with the OpenWeatherMap.
import requests
import time
from datetime import datetime
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=47791be1e8e28c36edc448c5489921fb

# %%
# 4). Retrieve the following information from the API call:
        # Latitude and longitude
        # Maximum temperature
        # Percent humidity
        # Percent cloudiness
        # Wind speed
        # Weather description (for example, clouds, fog, light rain, clear sky)
        
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(.05)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
   
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
                
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | magadi
# Processing Record 2 of Set 1 | tromso
# Processing Record 3 of Set 1 | cherskiy
# Processing Record 4 of Set 1 | butaritari
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | panama city
# Processing Record 7 of Set 1 | nikolskoye
# Processing Record 8 of Set 1 | thinadhoo
# Processing Record 9 of Set 1 | new norfolk
# Processing Record 10 of Set 1 | katangli
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | arraial do cabo
# Processing Record 13 of Set 1 | puerto ayora
# Processing Record 14 of Set 1 | los llanos de aridane
# Processing Record 15 of Set 1 | ust-kan
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | cape town
# Processing Record 18 of Set 1 | tiksi
# Processing Record 19 of Set 1 | barrow
# Processing Record 20 of Set 1 | lasa
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | saskylakh
# Processing Record 24 of Set 1 | jacareacanga
# Processing Record 25 of Set 1 | ribeira grande
# Processing Record 26 of Set 1 | vila velha
# Processing Record 27 of Set 1 | lisakovsk
# Processing Record 28 of Set 1 | yulara
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | kaitangata
# Processing Record 31 of Set 1 | simao
# Processing Record 32 of Set 1 | katsuura
# Processing Record 33 of Set 1 | shakawe
# Processing Record 34 of Set 1 | luanda
# Processing Record 35 of Set 1 | fukue
# Processing Record 36 of Set 1 | mar del plata
# Processing Record 37 of Set 1 | hilo
# Processing Record 38 of Set 1 | dongsheng
# Processing Record 39 of Set 1 | hami
# Processing Record 40 of Set 1 | urumqi
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 1 | volosovo
# Processing Record 44 of Set 1 | qaanaaq
# Processing Record 45 of Set 1 | teguldet
# Processing Record 46 of Set 1 | chemodanovka
# Processing Record 47 of Set 1 | airai
# Processing Record 48 of Set 1 | paamiut
# Processing Record 49 of Set 1 | bredasdorp
# Processing Record 50 of Set 1 | zhicheng
# Processing Record 1 of Set 2 | atuona
# Processing Record 2 of Set 2 | vao
# Processing Record 3 of Set 2 | garissa
# Processing Record 4 of Set 2 | umm kaddadah
# Processing Record 5 of Set 2 | mahebourg
# Processing Record 6 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 2 | weligama
# Processing Record 8 of Set 2 | fayetteville
# Processing Record 9 of Set 2 | suntar
# Processing Record 10 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 11 of Set 2 | saint-leu
# Processing Record 12 of Set 2 | castro
# Processing Record 13 of Set 2 | meulaboh
# Processing Record 14 of Set 2 | touros
# Processing Record 15 of Set 2 | la asuncion
# Processing Record 16 of Set 2 | talnakh
# Processing Record 17 of Set 2 | longyearbyen
# Processing Record 18 of Set 2 | hobart
# Processing Record 19 of Set 2 | khatanga
# Processing Record 20 of Set 2 | nongstoin
# Processing Record 21 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 2 | tolaga bay
# Processing Record 23 of Set 2 | haines junction
# Processing Record 24 of Set 2 | lamu
# Processing Record 25 of Set 2 | kavaratti
# Processing Record 26 of Set 2 | ontario
# Processing Record 27 of Set 2 | berlevag
# Processing Record 28 of Set 2 | albany
# Processing Record 29 of Set 2 | severo-kurilsk
# Processing Record 30 of Set 2 | barreirinha
# Processing Record 31 of Set 2 | hithadhoo
# Processing Record 32 of Set 2 | kapaa
# Processing Record 33 of Set 2 | vardo
# Processing Record 34 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 2 | santiago de cao
# Processing Record 36 of Set 2 | tura
# Processing Record 37 of Set 2 | half moon bay
# Processing Record 38 of Set 2 | kavieng
# Processing Record 39 of Set 2 | xining
# Processing Record 40 of Set 2 | sao sebastiao
# Processing Record 41 of Set 2 | cockburn town
# Processing Record 42 of Set 2 | boa vista
# Processing Record 43 of Set 2 | kungurtug
# Processing Record 44 of Set 2 | colares
# Processing Record 45 of Set 2 | harper
# Processing Record 46 of Set 2 | clara
# Processing Record 47 of Set 2 | nelson bay
# Processing Record 48 of Set 2 | cotonou
# Processing Record 49 of Set 2 | muzhi
# Processing Record 50 of Set 2 | coihaique
# Processing Record 1 of Set 3 | boo
# Processing Record 2 of Set 3 | tatvan
# Processing Record 3 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 3 | cacoal
# Processing Record 5 of Set 3 | buqayq
# City not found. Skipping...
# Processing Record 6 of Set 3 | kalat
# Processing Record 7 of Set 3 | jamestown
# Processing Record 8 of Set 3 | tabou
# Processing Record 9 of Set 3 | pacific grove
# Processing Record 10 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 3 | ferreira do alentejo
# Processing Record 12 of Set 3 | oga
# Processing Record 13 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 3 | geraldton
# Processing Record 15 of Set 3 | taltal
# Processing Record 16 of Set 3 | smithers
# Processing Record 17 of Set 3 | high rock
# Processing Record 18 of Set 3 | ballina
# Processing Record 19 of Set 3 | blagoyevo
# Processing Record 20 of Set 3 | muros
# Processing Record 21 of Set 3 | alofi
# Processing Record 22 of Set 3 | ambilobe
# Processing Record 23 of Set 3 | punta arenas
# Processing Record 24 of Set 3 | barcelos
# Processing Record 25 of Set 3 | aklavik
# Processing Record 26 of Set 3 | linqiong
# Processing Record 27 of Set 3 | linxia
# Processing Record 28 of Set 3 | carnarvon
# Processing Record 29 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 3 | bar harbor
# Processing Record 31 of Set 3 | ancud
# Processing Record 32 of Set 3 | corner brook
# Processing Record 33 of Set 3 | saint george
# Processing Record 34 of Set 3 | jacmel
# Processing Record 35 of Set 3 | balakovo
# Processing Record 36 of Set 3 | skegness
# Processing Record 37 of Set 3 | almeirim
# Processing Record 38 of Set 3 | kieta
# Processing Record 39 of Set 3 | ranong
# Processing Record 40 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 3 | katherine
# Processing Record 42 of Set 3 | mandera
# Processing Record 43 of Set 3 | bandarbeyla
# Processing Record 44 of Set 3 | saint-philippe
# Processing Record 45 of Set 3 | sobolevo
# Processing Record 46 of Set 3 | camacupa
# Processing Record 47 of Set 3 | tamandare
# Processing Record 48 of Set 3 | bure
# Processing Record 49 of Set 3 | voskresenskoye
# Processing Record 50 of Set 3 | sarankhola
# Processing Record 1 of Set 4 | kenai
# Processing Record 2 of Set 4 | dikson
# Processing Record 3 of Set 4 | san patricio
# Processing Record 4 of Set 4 | sorong
# Processing Record 5 of Set 4 | vila franca do campo
# Processing Record 6 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 4 | aleksandrovskiy zavod
# Processing Record 8 of Set 4 | tuktoyaktuk
# Processing Record 9 of Set 4 | axim
# Processing Record 10 of Set 4 | kargasok
# Processing Record 11 of Set 4 | yellowknife
# Processing Record 12 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 4 | pisco
# Processing Record 14 of Set 4 | bengkulu
# Processing Record 15 of Set 4 | miles city
# Processing Record 16 of Set 4 | ilulissat
# Processing Record 17 of Set 4 | iuna
# Processing Record 18 of Set 4 | sabha
# Processing Record 19 of Set 4 | lebu
# Processing Record 20 of Set 4 | sept-iles
# Processing Record 21 of Set 4 | togul
# Processing Record 22 of Set 4 | sumbe
# Processing Record 23 of Set 4 | avarua
# Processing Record 24 of Set 4 | victoria
# Processing Record 25 of Set 4 | peace river
# Processing Record 26 of Set 4 | salekhard
# Processing Record 27 of Set 4 | coquimbo
# Processing Record 28 of Set 4 | keti bandar
# Processing Record 29 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 4 | ilo
# Processing Record 31 of Set 4 | hohhot
# Processing Record 32 of Set 4 | atar
# Processing Record 33 of Set 4 | mirnyy
# Processing Record 34 of Set 4 | batsfjord
# Processing Record 35 of Set 4 | mayor pablo lagerenza
# Processing Record 36 of Set 4 | millbrook
# Processing Record 37 of Set 4 | del rio
# Processing Record 38 of Set 4 | ardakan
# Processing Record 39 of Set 4 | sao joao da barra
# Processing Record 40 of Set 4 | lagos
# Processing Record 41 of Set 4 | xadani
# City not found. Skipping...
# Processing Record 42 of Set 4 | barra patuca
# Processing Record 43 of Set 4 | chancay
# Processing Record 44 of Set 4 | tasiilaq
# Processing Record 45 of Set 4 | aberdeen
# Processing Record 46 of Set 4 | doha
# Processing Record 47 of Set 4 | ussel
# Processing Record 48 of Set 4 | port alfred
# Processing Record 49 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 4 | faya
# Processing Record 1 of Set 5 | fairmont
# Processing Record 2 of Set 5 | san matias
# Processing Record 3 of Set 5 | cidreira
# Processing Record 4 of Set 5 | bilma
# Processing Record 5 of Set 5 | acajutla
# Processing Record 6 of Set 5 | daru
# Processing Record 7 of Set 5 | chake chake
# Processing Record 8 of Set 5 | saldanha
# Processing Record 9 of Set 5 | olaine
# Processing Record 10 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 5 | souillac
# Processing Record 12 of Set 5 | thompson
# Processing Record 13 of Set 5 | sao gabriel da cachoeira
# Processing Record 14 of Set 5 | pundaguitan
# Processing Record 15 of Set 5 | araouane
# Processing Record 16 of Set 5 | rio grande
# Processing Record 17 of Set 5 | tawzar
# City not found. Skipping...
# Processing Record 18 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 19 of Set 5 | oil city
# Processing Record 20 of Set 5 | maloy
# Processing Record 21 of Set 5 | dingle
# Processing Record 22 of Set 5 | shreveport
# Processing Record 23 of Set 5 | narsaq
# Processing Record 24 of Set 5 | puerto baquerizo moreno
# Processing Record 25 of Set 5 | vostok
# Processing Record 26 of Set 5 | maralal
# Processing Record 27 of Set 5 | namibe
# Processing Record 28 of Set 5 | sola
# Processing Record 29 of Set 5 | monrovia
# Processing Record 30 of Set 5 | menton
# Processing Record 31 of Set 5 | saint-francois
# Processing Record 32 of Set 5 | port elizabeth
# Processing Record 33 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 5 | boende
# Processing Record 36 of Set 5 | hualmay
# Processing Record 37 of Set 5 | ormara
# Processing Record 38 of Set 5 | moerai
# Processing Record 39 of Set 5 | cuamba
# Processing Record 40 of Set 5 | clyde river
# Processing Record 41 of Set 5 | vilhena
# Processing Record 42 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 5 | nyanza
# Processing Record 44 of Set 5 | codrington
# Processing Record 45 of Set 5 | bonthe
# Processing Record 46 of Set 5 | sarangani
# Processing Record 47 of Set 5 | eseka
# Processing Record 48 of Set 5 | bambous virieux
# Processing Record 49 of Set 5 | esperance
# Processing Record 50 of Set 5 | upernavik
# Processing Record 1 of Set 6 | alihe
# Processing Record 2 of Set 6 | asheboro
# Processing Record 3 of Set 6 | klaksvik
# Processing Record 4 of Set 6 | caribou
# Processing Record 5 of Set 6 | lodja
# Processing Record 6 of Set 6 | sinnamary
# Processing Record 7 of Set 6 | coahuayana
# Processing Record 8 of Set 6 | ushtobe
# Processing Record 9 of Set 6 | uzumlu
# City not found. Skipping...
# Processing Record 10 of Set 6 | kodiak
# Processing Record 11 of Set 6 | wattegama
# Processing Record 12 of Set 6 | komsomolskiy
# Processing Record 13 of Set 6 | richards bay
# Processing Record 14 of Set 6 | tuy hoa
# Processing Record 15 of Set 6 | yar-sale
# Processing Record 16 of Set 6 | hasaki
# Processing Record 17 of Set 6 | portland
# Processing Record 18 of Set 6 | colomiers
# Processing Record 19 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 20 of Set 6 | labrea
# Processing Record 21 of Set 6 | hamilton
# Processing Record 22 of Set 6 | sangar
# Processing Record 23 of Set 6 | sao jose da coroa grande
# Processing Record 24 of Set 6 | east london
# Processing Record 25 of Set 6 | curup
# Processing Record 26 of Set 6 | olafsvik
# Processing Record 27 of Set 6 | jaque
# Processing Record 28 of Set 6 | cascais
# Processing Record 29 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 30 of Set 6 | nuevo progreso
# Processing Record 31 of Set 6 | sakakah
# Processing Record 32 of Set 6 | saint-pierre
# Processing Record 33 of Set 6 | guerrero negro
# Processing Record 34 of Set 6 | moron
# Processing Record 35 of Set 6 | sitka
# Processing Record 36 of Set 6 | pangnirtung
# Processing Record 37 of Set 6 | lorengau
# Processing Record 38 of Set 6 | roma
# Processing Record 39 of Set 6 | champerico
# Processing Record 40 of Set 6 | lucea
# Processing Record 41 of Set 6 | yenagoa
# Processing Record 42 of Set 6 | urbana
# Processing Record 43 of Set 6 | nadym
# Processing Record 44 of Set 6 | treinta y tres
# Processing Record 45 of Set 6 | morden
# Processing Record 46 of Set 6 | novyy urgal
# Processing Record 47 of Set 6 | havre-saint-pierre
# Processing Record 48 of Set 6 | biak
# Processing Record 49 of Set 6 | port hedland
# Processing Record 50 of Set 6 | bridlington
# Processing Record 1 of Set 7 | itarema
# Processing Record 2 of Set 7 | abu samrah
# Processing Record 3 of Set 7 | kegayli
# City not found. Skipping...
# Processing Record 4 of Set 7 | iqaluit
# Processing Record 5 of Set 7 | san cristobal
# Processing Record 6 of Set 7 | maceio
# Processing Record 7 of Set 7 | salalah
# Processing Record 8 of Set 7 | spornoye
# Processing Record 9 of Set 7 | palmer
# Processing Record 10 of Set 7 | fortuna
# Processing Record 11 of Set 7 | nantucket
# Processing Record 12 of Set 7 | tsurib
# Processing Record 13 of Set 7 | villamontes
# Processing Record 14 of Set 7 | aden
# Processing Record 15 of Set 7 | te anau
# Processing Record 16 of Set 7 | caravelas
# Processing Record 17 of Set 7 | ketchikan
# Processing Record 18 of Set 7 | torbay
# Processing Record 19 of Set 7 | jiayuguan
# Processing Record 20 of Set 7 | casas grandes
# Processing Record 21 of Set 7 | port lincoln
# Processing Record 22 of Set 7 | guane
# Processing Record 23 of Set 7 | umm ruwabah
# City not found. Skipping...
# Processing Record 24 of Set 7 | mahon
# Processing Record 25 of Set 7 | ouagadougou
# Processing Record 26 of Set 7 | svetlyy
# Processing Record 27 of Set 7 | hirara
# Processing Record 28 of Set 7 | sayat
# Processing Record 29 of Set 7 | belmonte
# Processing Record 30 of Set 7 | bethel
# Processing Record 31 of Set 7 | laguna
# Processing Record 32 of Set 7 | penzberg
# Processing Record 33 of Set 7 | pevek
# Processing Record 34 of Set 7 | ostrovnoy
# Processing Record 35 of Set 7 | leshan
# Processing Record 36 of Set 7 | kaspiyskiy
# Processing Record 37 of Set 7 | omboue
# Processing Record 38 of Set 7 | zwedru
# Processing Record 39 of Set 7 | lavrentiya
# Processing Record 40 of Set 7 | faanui
# Processing Record 41 of Set 7 | chokurdakh
# Processing Record 42 of Set 7 | gwadar
# Processing Record 43 of Set 7 | leningradskiy
# Processing Record 44 of Set 7 | hobyo
# Processing Record 45 of Set 7 | kainantu
# Processing Record 46 of Set 7 | necochea
# Processing Record 47 of Set 7 | vestmannaeyjar
# Processing Record 48 of Set 7 | evensk
# Processing Record 49 of Set 7 | georgetown
# Processing Record 50 of Set 7 | attock
# Processing Record 1 of Set 8 | makung
# City not found. Skipping...
# Processing Record 2 of Set 8 | le port
# Processing Record 3 of Set 8 | matara
# Processing Record 4 of Set 8 | sao felix do xingu
# Processing Record 5 of Set 8 | baikunthpur
# Processing Record 6 of Set 8 | peterhead
# Processing Record 7 of Set 8 | malanville
# Processing Record 8 of Set 8 | bubaque
# Processing Record 9 of Set 8 | ust-tsilma
# Processing Record 10 of Set 8 | dicabisagan
# Processing Record 11 of Set 8 | sundsvall
# Processing Record 12 of Set 8 | lompoc
# Processing Record 13 of Set 8 | inhambane
# Processing Record 14 of Set 8 | kushmurun
# Processing Record 15 of Set 8 | yanchukan
# City not found. Skipping...
# Processing Record 16 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 17 of Set 8 | san jose
# Processing Record 18 of Set 8 | sao miguel do araguaia
# Processing Record 19 of Set 8 | dalbandin
# Processing Record 20 of Set 8 | kontagora
# Processing Record 21 of Set 8 | luderitz
# Processing Record 22 of Set 8 | saint anthony
# Processing Record 23 of Set 8 | sabang
# Processing Record 24 of Set 8 | oranjemund
# Processing Record 25 of Set 8 | susanville
# Processing Record 26 of Set 8 | gijon
# Processing Record 27 of Set 8 | broken hill
# Processing Record 28 of Set 8 | rum
# Processing Record 29 of Set 8 | lagoa
# Processing Record 30 of Set 8 | port macquarie
# Processing Record 31 of Set 8 | minas novas
# Processing Record 32 of Set 8 | shahreza
# Processing Record 33 of Set 8 | oyama
# Processing Record 34 of Set 8 | antofagasta
# Processing Record 35 of Set 8 | liverpool
# Processing Record 36 of Set 8 | grand bank
# Processing Record 37 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 38 of Set 8 | yeletskiy
# City not found. Skipping...
# Processing Record 39 of Set 8 | karasburg
# Processing Record 40 of Set 8 | vanavara
# Processing Record 41 of Set 8 | kathmandu
# Processing Record 42 of Set 8 | loukhi
# Processing Record 43 of Set 8 | temerloh
# Processing Record 44 of Set 8 | chapais
# Processing Record 45 of Set 8 | novaya lyalya
# Processing Record 46 of Set 8 | krasnyy oktyabr
# Processing Record 47 of Set 8 | egvekinot
# Processing Record 48 of Set 8 | sahrak
# City not found. Skipping...
# Processing Record 49 of Set 8 | shenjiamen
# Processing Record 50 of Set 8 | asbury park
# Processing Record 1 of Set 9 | bialystok
# Processing Record 2 of Set 9 | cayhagan
# Processing Record 3 of Set 9 | hearst
# Processing Record 4 of Set 9 | guarapari
# Processing Record 5 of Set 9 | khasan
# Processing Record 6 of Set 9 | suruc
# Processing Record 7 of Set 9 | calama
# Processing Record 8 of Set 9 | nome
# Processing Record 9 of Set 9 | tarko-sale
# Processing Record 10 of Set 9 | cabedelo
# Processing Record 11 of Set 9 | bol
# Processing Record 12 of Set 9 | beringovskiy
# Processing Record 13 of Set 9 | rocha
# Processing Record 14 of Set 9 | maldonado
# Processing Record 15 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 9 | mattru
# Processing Record 17 of Set 9 | podporozhye
# Processing Record 18 of Set 9 | provideniya
# Processing Record 19 of Set 9 | rudbar
# Processing Record 20 of Set 9 | bathsheba
# Processing Record 21 of Set 9 | koumac
# Processing Record 22 of Set 9 | kysyl-syr
# Processing Record 23 of Set 9 | san miguel
# Processing Record 24 of Set 9 | hay river
# Processing Record 25 of Set 9 | port blair
# Processing Record 26 of Set 9 | winnemucca
# Processing Record 27 of Set 9 | sterling
# Processing Record 28 of Set 9 | kruisfontein
# Processing Record 29 of Set 9 | pitimbu
# Processing Record 30 of Set 9 | devils lake
# Processing Record 31 of Set 9 | toora-khem
# Processing Record 32 of Set 9 | marawi
# Processing Record 33 of Set 9 | solnechnyy
# Processing Record 34 of Set 9 | isangel
# Processing Record 35 of Set 9 | tiznit
# Processing Record 36 of Set 9 | nuuk
# Processing Record 37 of Set 9 | adrar
# Processing Record 38 of Set 9 | praia da vitoria
# Processing Record 39 of Set 9 | porto novo
# Processing Record 40 of Set 9 | sao miguel do tapuio
# Processing Record 41 of Set 9 | rovaniemi
# Processing Record 42 of Set 9 | seydi
# Processing Record 43 of Set 9 | mount isa
# Processing Record 44 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 9 | wajir
# Processing Record 46 of Set 9 | shingu
# Processing Record 47 of Set 9 | solano
# Processing Record 48 of Set 9 | saint marys
# Processing Record 49 of Set 9 | ust-ordynskiy
# Processing Record 50 of Set 9 | eureka
# Processing Record 1 of Set 10 | agirish
# Processing Record 2 of Set 10 | qeshm
# Processing Record 3 of Set 10 | saleilua
# City not found. Skipping...
# Processing Record 4 of Set 10 | popondetta
# Processing Record 5 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 6 of Set 10 | beloha
# Processing Record 7 of Set 10 | virginia beach
# Processing Record 8 of Set 10 | doembang nangbuat
# Processing Record 9 of Set 10 | norman wells
# Processing Record 10 of Set 10 | erenhot
# Processing Record 11 of Set 10 | luzhou
# Processing Record 12 of Set 10 | elk river
# Processing Record 13 of Set 10 | slave lake
# Processing Record 14 of Set 10 | bajo baudo
# City not found. Skipping...
# Processing Record 15 of Set 10 | chateaubelair
# Processing Record 16 of Set 10 | pacifica
# Processing Record 17 of Set 10 | preili
# Processing Record 18 of Set 10 | sao filipe
# Processing Record 19 of Set 10 | naze
# Processing Record 20 of Set 10 | floro
# Processing Record 21 of Set 10 | remanso
# Processing Record 22 of Set 10 | forbes
# Processing Record 23 of Set 10 | alghero
# Processing Record 24 of Set 10 | north platte
# Processing Record 25 of Set 10 | chuy
# Processing Record 26 of Set 10 | bassila
# Processing Record 27 of Set 10 | iles
# Processing Record 28 of Set 10 | chiantla
# Processing Record 29 of Set 10 | cedral
# Processing Record 30 of Set 10 | springfield
# Processing Record 31 of Set 10 | stromness
# Processing Record 32 of Set 10 | englewood
# Processing Record 33 of Set 10 | husavik
# Processing Record 34 of Set 10 | ambon
# Processing Record 35 of Set 10 | urgut
# Processing Record 36 of Set 10 | tomatlan
# Processing Record 37 of Set 10 | san quintin
# Processing Record 38 of Set 10 | asau
# Processing Record 39 of Set 10 | caborca
# Processing Record 40 of Set 10 | cody
# Processing Record 41 of Set 10 | fort nelson
# Processing Record 42 of Set 10 | wingham
# Processing Record 43 of Set 10 | saint-joseph
# Processing Record 44 of Set 10 | shimoda
# Processing Record 45 of Set 10 | finschhafen
# Processing Record 46 of Set 10 | brezice
# Processing Record 47 of Set 10 | pilot butte
# Processing Record 48 of Set 10 | correntina
# Processing Record 49 of Set 10 | kidal
# Processing Record 50 of Set 10 | bowen
# Processing Record 1 of Set 11 | solenzo
# Processing Record 2 of Set 11 | mangit
# Processing Record 3 of Set 11 | port augusta
# Processing Record 4 of Set 11 | hede
# Processing Record 5 of Set 11 | gari
# Processing Record 6 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 7 of Set 11 | khao wong
# Processing Record 8 of Set 11 | salamiyah
# Processing Record 9 of Set 11 | ogaminana
# Processing Record 10 of Set 11 | kahta
# Processing Record 11 of Set 11 | bhimunipatnam
# Processing Record 12 of Set 11 | morondava
# Processing Record 13 of Set 11 | qaqortoq
# Processing Record 14 of Set 11 | ahipara
# Processing Record 15 of Set 11 | shelburne
# Processing Record 16 of Set 11 | kerema
# Processing Record 17 of Set 11 | mecca
# Processing Record 18 of Set 11 | markova
# Processing Record 19 of Set 11 | sibolga
# Processing Record 20 of Set 11 | manicore
# Processing Record 21 of Set 11 | zheleznogorsk-ilimskiy
# Processing Record 22 of Set 11 | torata
# Processing Record 23 of Set 11 | cayenne
# Processing Record 24 of Set 11 | rohru
# Processing Record 25 of Set 11 | vieux fort
# Processing Record 26 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 27 of Set 11 | carmen
# Processing Record 28 of Set 11 | lata
# Processing Record 29 of Set 11 | kilimatinde
# Processing Record 30 of Set 11 | cooma
# Processing Record 31 of Set 11 | skjervoy
# Processing Record 32 of Set 11 | pushkinskiye gory
# Processing Record 33 of Set 11 | georgiyevka
# Processing Record 34 of Set 11 | nueva loja
# Processing Record 35 of Set 11 | beyneu
# Processing Record 36 of Set 11 | tiruvottiyur
# City not found. Skipping...
# Processing Record 37 of Set 11 | mayo
# Processing Record 38 of Set 11 | nanortalik
# Processing Record 39 of Set 11 | agbor
# Processing Record 40 of Set 11 | ayaviri
# Processing Record 41 of Set 11 | riyadh
# Processing Record 42 of Set 11 | college
# Processing Record 43 of Set 11 | ixtapa
# Processing Record 44 of Set 11 | chegutu
# Processing Record 45 of Set 11 | dalton
# Processing Record 46 of Set 11 | san policarpo
# Processing Record 47 of Set 11 | karaton
# Processing Record 48 of Set 11 | cairns
# Processing Record 49 of Set 11 | mayumba
# Processing Record 50 of Set 11 | bull savanna
# Processing Record 1 of Set 12 | baneh
# Processing Record 2 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 3 of Set 12 | mahanoro
# Processing Record 4 of Set 12 | maamba
# Processing Record 5 of Set 12 | cockburn harbour
# City not found. Skipping...
# Processing Record 6 of Set 12 | palekh
# Processing Record 7 of Set 12 | tabuk
# Processing Record 8 of Set 12 | vitim
# Processing Record 9 of Set 12 | antalaha
# Processing Record 10 of Set 12 | muroto
# Processing Record 11 of Set 12 | bor
# Processing Record 12 of Set 12 | mulege
# Processing Record 13 of Set 12 | trairi
# Processing Record 14 of Set 12 | nea kallikratia
# Processing Record 15 of Set 12 | varginha
# Processing Record 16 of Set 12 | solwezi
# Processing Record 17 of Set 12 | natal
# Processing Record 18 of Set 12 | gerede
# Processing Record 19 of Set 12 | mao
# Processing Record 20 of Set 12 | anshun
# Processing Record 21 of Set 12 | sioux lookout
# Processing Record 22 of Set 12 | ust-maya
# Processing Record 23 of Set 12 | priargunsk
# Processing Record 24 of Set 12 | tupiza
# Processing Record 25 of Set 12 | tessalit
# Processing Record 26 of Set 12 | zhigansk
# Processing Record 27 of Set 12 | timmins
# Processing Record 28 of Set 12 | marzuq
# Processing Record 29 of Set 12 | estacion coahuila
# Processing Record 30 of Set 12 | yabrud
# Processing Record 31 of Set 12 | deer lake
# Processing Record 32 of Set 12 | ardistan
# City not found. Skipping...
# Processing Record 33 of Set 12 | balakhninskiy
# Processing Record 34 of Set 12 | olean
# Processing Record 35 of Set 12 | manali
# Processing Record 36 of Set 12 | pocatello
# Processing Record 37 of Set 12 | ponta do sol
# Processing Record 38 of Set 12 | shu
# Processing Record 39 of Set 12 | grand gaube
# Processing Record 40 of Set 12 | alexandria
# Processing Record 41 of Set 12 | hamina
# Processing Record 42 of Set 12 | sainte-anne-des-monts
# Processing Record 43 of Set 12 | kon tum
# Processing Record 44 of Set 12 | saint-louis
# Processing Record 45 of Set 12 | acarau
# Processing Record 46 of Set 12 | hovd
# Processing Record 47 of Set 12 | yumen
# Processing Record 48 of Set 12 | akyab
# Processing Record 49 of Set 12 | ust-nera
# Processing Record 50 of Set 12 | boyuibe
# Processing Record 1 of Set 13 | atascadero
# Processing Record 2 of Set 13 | luan
# Processing Record 3 of Set 13 | barcelona
# Processing Record 4 of Set 13 | sambava
# Processing Record 5 of Set 13 | la ronge
# Processing Record 6 of Set 13 | conceicao do araguaia
# Processing Record 7 of Set 13 | kenora
# Processing Record 8 of Set 13 | peniche
# Processing Record 9 of Set 13 | ayan
# Processing Record 10 of Set 13 | beinamar
# Processing Record 11 of Set 13 | port-gentil
# Processing Record 12 of Set 13 | abha
# Processing Record 13 of Set 13 | erdemli
# Processing Record 14 of Set 13 | fairbanks
# Processing Record 15 of Set 13 | carson city
# Processing Record 16 of Set 13 | gravelbourg
# Processing Record 17 of Set 13 | margate
# Processing Record 18 of Set 13 | torrington
# Processing Record 19 of Set 13 | beruni
# City not found. Skipping...
# Processing Record 20 of Set 13 | agadez
# Processing Record 21 of Set 13 | maniitsoq
# Processing Record 22 of Set 13 | pangody
# Processing Record 23 of Set 13 | itoman
# Processing Record 24 of Set 13 | semey
# Processing Record 25 of Set 13 | sao lourenco do oeste
# Processing Record 26 of Set 13 | chau doc
# Processing Record 27 of Set 13 | lima
# Processing Record 28 of Set 13 | maua
# Processing Record 29 of Set 13 | witbank
# Processing Record 30 of Set 13 | ingham
# Processing Record 31 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 13 | bichura
# Processing Record 33 of Set 13 | vadso
# Processing Record 34 of Set 13 | huilong
# Processing Record 35 of Set 13 | islamkot
# Processing Record 36 of Set 13 | rorvik
# Processing Record 37 of Set 13 | bongandanga
# Processing Record 38 of Set 13 | auburn
# Processing Record 39 of Set 13 | cheney
# Processing Record 40 of Set 13 | hokitika
# Processing Record 41 of Set 13 | mogochin
# City not found. Skipping...
# Processing Record 42 of Set 13 | taybad
# Processing Record 43 of Set 13 | ascension
# Processing Record 44 of Set 13 | kuching
# Processing Record 45 of Set 13 | isla vista
# Processing Record 46 of Set 13 | imbituba
# Processing Record 47 of Set 13 | obihiro
# Processing Record 48 of Set 13 | boguchany
# Processing Record 49 of Set 13 | chihuahua
# Processing Record 50 of Set 13 | la paz centro
# Processing Record 1 of Set 14 | surt
# Processing Record 2 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 14 | saint-augustin
# Processing Record 4 of Set 14 | mount gambier
# Processing Record 5 of Set 14 | wuan
# Processing Record 6 of Set 14 | yichang
# Processing Record 7 of Set 14 | nishihara
# Processing Record 8 of Set 14 | galgani
# City not found. Skipping...
# Processing Record 9 of Set 14 | gornopravdinsk
# Processing Record 10 of Set 14 | hofn
# Processing Record 11 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 14 | chokwe
# Processing Record 13 of Set 14 | okhotsk
# Processing Record 14 of Set 14 | kaeo
# Processing Record 15 of Set 14 | leshukonskoye
# Processing Record 16 of Set 14 | porto velho
# Processing Record 17 of Set 14 | petrivka
# Processing Record 18 of Set 14 | tuensang
# Processing Record 19 of Set 14 | clarksdale
# Processing Record 20 of Set 14 | busovaca
# Processing Record 21 of Set 14 | charagua
# Processing Record 22 of Set 14 | nara
# Processing Record 23 of Set 14 | san rafael
# Processing Record 24 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 25 of Set 14 | develi
# Processing Record 26 of Set 14 | mae hong son
# Processing Record 27 of Set 14 | jining
# Processing Record 28 of Set 14 | sault sainte marie
# Processing Record 29 of Set 14 | zhezkazgan
# Processing Record 30 of Set 14 | constitucion
# Processing Record 31 of Set 14 | gao
# Processing Record 32 of Set 14 | salinopolis
# Processing Record 33 of Set 14 | goundi
# Processing Record 34 of Set 14 | lipari
# Processing Record 35 of Set 14 | arroyos y esteros
# Processing Record 36 of Set 14 | nemuro
# Processing Record 37 of Set 14 | pangai
# Processing Record 38 of Set 14 | ugoofaaru
# Processing Record 39 of Set 14 | poum
# Processing Record 40 of Set 14 | loreto
# Processing Record 41 of Set 14 | tulun
# Processing Record 42 of Set 14 | aswan
# Processing Record 43 of Set 14 | taunsa
# Processing Record 44 of Set 14 | oistins
# Processing Record 45 of Set 14 | kawalu
# Processing Record 46 of Set 14 | bairiki
# Processing Record 47 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 14 | chernyshevskiy
# Processing Record 49 of Set 14 | chetumal
# Processing Record 50 of Set 14 | borujan
# City not found. Skipping...
# Processing Record 1 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 2 of Set 15 | buraydah
# Processing Record 3 of Set 15 | tungkang
# City not found. Skipping...
# Processing Record 4 of Set 15 | iwakuni
# Processing Record 5 of Set 15 | karpathos
# Processing Record 6 of Set 15 | sampit
# Processing Record 7 of Set 15 | srednekolymsk
# Processing Record 8 of Set 15 | bitung
# Processing Record 9 of Set 15 | muli
# Processing Record 10 of Set 15 | koulikoro
# Processing Record 11 of Set 15 | emilio carranza
# Processing Record 12 of Set 15 | hambantota
# Processing Record 13 of Set 15 | kahului
# Processing Record 14 of Set 15 | chicama
# Processing Record 15 of Set 15 | san carlos de bariloche
# Processing Record 16 of Set 15 | korla
# Processing Record 17 of Set 15 | tautira
# Processing Record 18 of Set 15 | cheyenne
# Processing Record 19 of Set 15 | odweyne
# Processing Record 20 of Set 15 | porlamar
# Processing Record 21 of Set 15 | altay
# Processing Record 22 of Set 15 | syracuse
# Processing Record 23 of Set 15 | tokur
# Processing Record 24 of Set 15 | izumo
# Processing Record 25 of Set 15 | linhares
# Processing Record 26 of Set 15 | lokosovo
# Processing Record 27 of Set 15 | tazovskiy
# Processing Record 28 of Set 15 | kaohsiung
# Processing Record 29 of Set 15 | borovoy
# Processing Record 30 of Set 15 | palmares do sul
# Processing Record 31 of Set 15 | viedma
# Processing Record 32 of Set 15 | zeerust
# Processing Record 33 of Set 15 | port hardy
# Processing Record 34 of Set 15 | karratha
# Processing Record 35 of Set 15 | yomitan
# City not found. Skipping...
# Processing Record 36 of Set 15 | mehamn
# Processing Record 37 of Set 15 | parainen
# Processing Record 38 of Set 15 | nyurba
# Processing Record 39 of Set 15 | acapulco
# Processing Record 40 of Set 15 | de-kastri
# Processing Record 41 of Set 15 | nha trang
# Processing Record 42 of Set 15 | rio gallegos
# Processing Record 43 of Set 15 | roald
# Processing Record 44 of Set 15 | venado tuerto
# Processing Record 45 of Set 15 | neiafu
# Processing Record 46 of Set 15 | mbandaka
# Processing Record 47 of Set 15 | kencong
# Processing Record 48 of Set 15 | ekhabi
# Processing Record 49 of Set 15 | naron
# Processing Record 50 of Set 15 | hvammstangi
# City not found. Skipping...
# Processing Record 1 of Set 16 | sawtell
# Processing Record 2 of Set 16 | praia
# Processing Record 3 of Set 16 | gayny
# Processing Record 4 of Set 16 | launceston
# Processing Record 5 of Set 16 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 16 | calvinia
# Processing Record 7 of Set 16 | heishan
# Processing Record 8 of Set 16 | hienghene
# Processing Record 9 of Set 16 | phangnga
# Processing Record 10 of Set 16 | moranbah
# Processing Record 11 of Set 16 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 16 | batemans bay
# Processing Record 13 of Set 16 | alice springs
# Processing Record 14 of Set 16 | tual
# Processing Record 15 of Set 16 | bintulu
# Processing Record 16 of Set 16 | enumclaw
# Processing Record 17 of Set 16 | kisangani
# Processing Record 18 of Set 16 | huarmey
# Processing Record 19 of Set 16 | dera ghazi khan
# Processing Record 20 of Set 16 | rutana
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 712

# %%
# 5) Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Magadi  12.9667   77.2333     82.45        71           0        9.01
# 1       Tromso  69.6496   18.9570     26.62        68          75       18.41
# 2     Cherskiy  68.7500  161.3000     31.86       100         100        4.27
# 3   Butaritari   3.0707  172.7902     81.45        80          70       15.35
# 4        Bluff -46.6000  168.3333     55.80        67          96        6.53
# 5  Panama City   8.9936  -79.5197     76.95        90          75        3.44
# 6   Nikolskoye  59.7035   30.7861     31.87        76          26        4.12
# 7    Thinadhoo   0.5333   72.9333     83.82        73          99        6.15
# 8  New Norfolk -42.7826  147.0587     70.92        83          60        2.57
# 9     Katangli  51.7102  143.2326     30.60        84         100       30.85
#
#   Country Weather Description
# 0      IN           clear sky
# 1      NO          light snow
# 2      RU          light snow
# 3      KI       broken clouds
# 4      NZ     overcast clouds
# 5      PA       broken clouds
# 6      RU    scattered clouds
# 7      MV     overcast clouds
# 8      AU       broken clouds
# 9      RU     overcast clouds

# %%
# 6) Export the DataFrame as a CSV file
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\TIERNA~1\AppData\Local\Temp/ipykernel_10580/1744610774.py in <module>
#       1 # 6) Export the DataFrame as a CSV file
#       2 output_data_file = "Weather_Database/WeatherPy_Database.csv"
# ----> 3 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     235         """
#     236         # apply compression and byte/text conversion
# --> 237         with get_handle(
#     238             self.filepath_or_buffer,
#     239             self.mode,
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/WeatherPy_Database.csv'
